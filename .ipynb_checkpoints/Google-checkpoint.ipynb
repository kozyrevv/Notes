# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
adwords=pd.read_excel('adwords.csv')
df=pd.DataFrame(adwords)

# %%
adwords.head()
# Out:
#    Hour  Week day Churn  Page/session
# 0   6.0       1.0    0            1.0
# 1   8.0       1.0    0            1.0
# 2  18.0       4.0    0            1.0
# 3   2.0       3.0    0            1.0
# 4   4.0       3.0    0            1.0

# %%
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
churn=df[(df['Page/session']==1) & (df['Week day'])]

# %%
sns.distplot(churn['Week day'])

# %%
df.head()
# Out:
#    Hour  Week day Churn  Page/session
# 0   6.0       1.0    0            1.0
# 1   8.0       1.0    0            1.0
# 2  18.0       4.0    0            1.0
# 3   2.0       3.0    0            1.0
# 4   4.0       3.0    0            1.0

# %%
churn = df>2

# %%
sns.jointplot(data=df, x='Week day', y='Page/session', kind='kde', hue='Churn',)

# %%
sns.heatmap(df.corr(),annot=True,)

# %%
sns.boxplot(data=df, x='Week day', y='Page/session')

# %%
sns.lmplot(data=df, x='Week day', y='Page/session', hue='Churn')

# %%
fig=plt.figure()

# %%
axes=fig.add_axes([0.1,0.1,8,8])
